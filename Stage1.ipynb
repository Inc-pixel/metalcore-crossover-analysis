# %% [markdown]
# <a href="https://colab.research.google.com/github/Inc-pixel/metalcore-crossover-analysis/blob/main/Stage1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from itertools import combinations

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats, integrate
from statsmodels.stats.oneway import anova_oneway
from statsmodels.stats.multitest import multipletests

os.makedirs("figures", exist_ok=True)   # folder for saved charts
pd.set_option("display.width", 160)     # wider printed tables

# %%
from google.colab import drive
drive.mount("/content/drive")
os.chdir("/content/drive/MyDrive/heavier-than-thou")   # your project folder
